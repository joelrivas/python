# %%
import os

# %%
import pandas as pd

# %%
import numpy as np

# %%
from geopy.geocoders import Nominatim

# %%
dm = pandas.DataFrame({'ID'      : pd.Categorical([2,4,5,6]),
                       'Address' : pd.Categorical(["735 Dolores St", "3995 23 St", "1056 Sanchez St", "551 Alvarado St"]),
                       'City_y'  : pd.Categorical(["CA 94119", "CA 94114", "California", "CA 94114"])
})

# %%
dm
# Out:
#            Address      City_y ID
# 0   735 Dolores St    CA 94119  2
# 1       3995 23 St    CA 94114  4
# 2  1056 Sanchez St  California  5
# 3  551 Alvarado St    CA 94114  6

# %%
df=pd.DataFrame({})

# %%
df["ID"] = [2,4,5,6]

# %%
df
# Out:
#    ID
# 0   2
# 1   4
# 2   5
# 3   6

# %%
df["Address"] = ["735 Dolores St","3995 23rd St","1056 Sanchez St","551 Alvarado St"]

# %%
df["City_x"]  = df.shape[0]*["San Francisco"]
df["State_x"] = ["CA 94119","CA 94114","California","CA 94114"]
df["Country"] = df.shape[0]*["USA"]
df["Name_x"]  = ["Bready Shop","Ben's Shop","Sanchez","Richvalley"]
df["Employees_x"] = [15,10,12,30]
df
# Out:
#    ID          Address         City_x     State_x Country       Name_x  \
# 0   2   735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# 1   4     3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# 2   5  1056 Sanchez St  San Francisco  California     USA      Sanchez
# 3   6  551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#    Employees_x
# 0           15
# 1           10
# 2           12
# 3           30

# %%
df["City_y"] = df["City_x"]

# %%
df
# Out:
#    ID          Address         City_x     State_x Country       Name_x  \
# 0   2   735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# 1   4     3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# 2   5  1056 Sanchez St  San Francisco  California     USA      Sanchez
# 3   6  551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#    Employees_x         City_y
# 0           15  San Francisco
# 1           10  San Francisco
# 2           12  San Francisco
# 3           30  San Francisco

# %%
df["Country_y"] = df["Country"]
df["Employees_y"]=df["Employees_x"]
df["Name_y"]=df["Name_x"]
df["State_y"]=df["State_x"]
df["Continent"]=df["Country"]+", "+"North America"
df
# Out:
#    ID          Address         City_x     State_x Country       Name_x  \
# 0   2   735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# 1   4     3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# 2   5  1056 Sanchez St  San Francisco  California     USA      Sanchez
# 3   6  551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#    Employees_x         City_y Country_y  Employees_y       Name_y     State_y  \
# 0           15  San Francisco       USA           15  Bready Shop    CA 94119
# 1           10  San Francisco       USA           10   Ben's Shop    CA 94114
# 2           12  San Francisco       USA           12      Sanchez  California
# 3           30  San Francisco       USA           30   Richvalley    CA 94114
#
#             Continent
# 0  USA, North America
# 1  USA, North America
# 2  USA, North America
# 3  USA, North America

# %%
df=df.rename(columns = {'Country':'Country_x'})

# %%
df
# Out:
#    ID          Address         City_x     State_x Country_x       Name_x  \
# 0   2   735 Dolores St  San Francisco    CA 94119       USA  Bready Shop
# 1   4     3995 23rd St  San Francisco    CA 94114       USA   Ben's Shop
# 2   5  1056 Sanchez St  San Francisco  California       USA      Sanchez
# 3   6  551 Alvarado St  San Francisco    CA 94114       USA   Richvalley
#
#    Employees_x         City_y Country_y  Employees_y       Name_y     State_y  \
# 0           15  San Francisco       USA           15  Bready Shop    CA 94119
# 1           10  San Francisco       USA           10   Ben's Shop    CA 94114
# 2           12  San Francisco       USA           12      Sanchez  California
# 3           30  San Francisco       USA           30   Richvalley    CA 94114
#
#             Continent
# 0  USA, North America
# 1  USA, North America
# 2  USA, North America
# 3  USA, North America

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim(scheme='http')

# %%
nom.geocode("2995 23rd St, San Francisco, CA 94114")
# Out:
# Location(23rd Street, Noe Valley, SF, California, 94114, United States of America, (37.7532569, -122.4281654, 0.0))

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995, 23rd Street, Noe Valley, SF, California, 94114, United States of America, (37.7529648, -122.4317141, 0.0))

# %%
df = pd.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates[0]
# Out:
# Location(21st Street, Mission District, SF, California, 94114, United States of America, (37.7570511, -122.4188036, 0.0))

# %%
df.Coordinates[0].latitude
# Out:
# 37.7570511

# %%
df.Coordinates[0].longitude
# Out:
# -122.4188036

# %%
df.Coordinates[0].altitude
# Out:
# 0.0

# %%
df.Coordinates[1].latitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-6eaa754a707a> in <module>()
# ----> 1 df.Coordinates[1].latitude
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# ...

# %%
df["Longitude"] = df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
